# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('evaluation/eval_results_updated.csv')
df.head()
# Out:
#                                        query          expected_file  \
# 0                      What is tuberculosis?                 FAQ.md
# 1                          How is TB spread?                 FAQ.md
# 2       What are the symptoms of TB disease?  Signs_and_Symptoms.md
# 3  What are the symptoms of TB in the brain?  Signs_and_Symptoms.md
# 4               What is latent TB infection?                 FAQ.md
#
#                                      expected_answer  search_time  chat_time  \
# 0  Tuberculosis (TB) is caused by a bacterium cal...        1.696      3.969
# 1  TB is spread through the air from one person t...        0.360      4.524
# 2  The most common form of TB affects the lungs (...        0.468      3.670
# 3  TB of the Brain/Central Nervous System: Severe...        0.486      2.910
# 4  Latent TB infection occurs when TB germs are i...        0.385      2.633
#
#                                        search_answer search_toxicity  \
# ...

# %%
df['search_time'].describe().T
# Out:
# count    45.000000
# mean      0.319378
# std       0.253230
# min       0.026000
# 25%       0.250000
# 50%       0.305000
# 75%       0.373000
# max       1.696000
# Name: search_time, dtype: float64

# %%
df['chat_time'].describe().T
# Out:
# count    45.000000
# mean      3.075156
# std       1.671914
# min       0.023000
# 25%       2.653000
# 50%       3.353000
# 75%       3.917000
# max       6.691000
# Name: chat_time, dtype: float64

# %%
df2 = pd.read_csv("evaluation/eval_results_chunks.csv")
df2.head(2)
# Out:
#                    query expected_file  \
# 0  What is tuberculosis?        FAQ.md
# 1      How is TB spread?        FAQ.md
#
#                                      expected_answer  search_time  chat_time  \
# 0  Tuberculosis (TB) is caused by a bacterium cal...        1.696      3.969
# 1  TB is spread through the air from one person t...        0.360      4.524
#
#                                        search_answer search_toxicity  \
# 0  **A:** Tuberculosis (TB) is caused by a bacter...       NOT_TOXIC
# 1  **A:** TB is spread through the air from one p...       NOT_TOXIC
#
#                                          chat_answer chat_toxicity  \
# 0  Tuberculosis (TB) is caused by a bacterium cal...     NOT_TOXIC
# 1  TB is spread through the air from one person t...     NOT_TOXIC
#
#                                      search_response  \
# 0  {"query": "What is tuberculosis?", "total_matc...
# 1  {"query": "How is TB spread?", "total_matches"...
#
# ...

# %%
df2['ground_truth'].head(2)
# Out:
# 0    # Frequently Asked Questions (FAQ)\n\n*Sources...
# 1    # Frequently Asked Questions (FAQ)\n\n*Sources...
# Name: ground_truth, dtype: object

# %%
js = pd.read_json("chunks.json")
js.head(3)
# Out:
#                                                 text  \
# 0  # TB Diagnosis Methods and Procedures\n\n*Sour...
# 1  WHO recommends the use of **rapid molecular di...
# 2  • **Xpert MTB/RIF Ultra**\n  - High diagnostic...
#
#                                               header   source_file  \
# 0                                                     Diagnosis.md
# 1                                        ## Overview  Diagnosis.md
# 2  #### Rapid Molecular Diagnostic Tests (Recomme...  Diagnosis.md
#
#                                           source_url
# 0  https://www.who.int/news-room/fact-sheets/deta...
# 1  https://www.who.int/news-room/fact-sheets/deta...
# 2  https://www.who.int/news-room/fact-sheets/deta...

# %%
dd = pd.read_csv("evaluation/eval_results_chunks_sentence.csv")
dd.head(2)
# Out:
#                    query expected_file  \
# 0  What is tuberculosis?        FAQ.md
# 1      How is TB spread?        FAQ.md
#
#                                      expected_answer  search_time  chat_time  \
# 0  Tuberculosis (TB) is caused by a bacterium cal...        1.696      3.969
# 1  TB is spread through the air from one person t...        0.360      4.524
#
#                                        search_answer search_toxicity  \
# 0  **A:** Tuberculosis (TB) is caused by a bacter...       NOT_TOXIC
# 1  **A:** TB is spread through the air from one p...       NOT_TOXIC
#
#                                          chat_answer chat_toxicity  \
# 0  Tuberculosis (TB) is caused by a bacterium cal...     NOT_TOXIC
# 1  TB is spread through the air from one person t...     NOT_TOXIC
#
#                                      search_response  \
# 0  {"query": "What is tuberculosis?", "total_matc...
# 1  {"query": "How is TB spread?", "total_matches"...
#
# ...

# %%
dd.columns.to_list()
# Out:
# ['query',
#  'expected_file',
#  'expected_answer',
#  'search_time',
#  'chat_time',
#  'search_answer',
#  'search_toxicity',
#  'chat_answer',
#  'chat_toxicity',
#  'search_response',
#  'chat_response',
#  'ground_truth',
#  'ground_truth_sentence']
